# %%
""" ---------------------------------
# 
#  class
# 
#   ----------------------------------
""" 
class UserDTO:

    def __init__(self):
        self.__userId : int
        self.__name : str
        self.__password : str
        self.__auth : int
        self.__address : str
            
    
    # setter
    def setAll(self, userId:int, name:str, password:str, auth:int, address:str):
        self.__userId = userId
        self.__name = name
        self.__password = password
        self.__auth = auth
        self.__address = address
    
    def setAllByTuple(self, userList:tuple):    
        self.__userId = userList[0]
        self.__name = userList[1]
        self.__password = userList[2]
        self.__auth = userList[3]
        self.__address = userList[4]
    
    def setId(self, userId:int):
        self.__userId = userId
        
    def setName(self, name:str):
        self.__name = name
        
    def setPass(self, password:str):
        self.__password = password
    
    def setAuth(self, auth:int):
        self.__auth = auth
        
    def setAddress(self, address:str):
        self.address = address

        
    # getter
    def getId(self)->int:
        return self.__userId
    
    def getName(self)->str:
        return self.__name
    
    def getPass(self)->str:
        return self.__password
    
    def getAuth(self)->int:
        return self.__auth
    
    def getAddress(self)->str:
        return self.__address
    
    
    # print
    def printUser(self):
        print(self.__userId)
        print(self.__name)
        print(self.__password)
        print(self.__auth)
        print(self.__address)

    """    
    user = UserDTO()
    user.setAll(1,"smp1","pass1",1,"aaa")
    user.printUser()
    """

# %%
""" ---------------------------------
# 
#  class
# 
#   ----------------------------------
""" 
import psycopg2
import os
class TransactionManagerByPostgres:
    
    dsn ="dbname=sample user=sample1"
    # dsn = os.environ.get('DATABASE_URL')
    # DATABASE_URL = postgresql://{username}:{password}@{hostname}:{port}/{database}
    
    def __init__(self):
        conn : psycopg2.extensions.connection
        cur  : psycopg2.extensions.connection.cursor
            
    def __del__(self):
        # デストラクタ
        print("さようなら")


    def setConnection(self):
        try:
            # postgres
            self.conn = psycopg2.connect(self.dsn)
        except OperationalError as e:
            print("OperationalError")
            raise e
    
    def getConnection(self) -> psycopg2.extensions.connection:
        try:
            """
            self.conn = psycopg2.connect(dsn)
            return self.conn
            """
            return psycopg2.connect(self.dsn)
        except OperationalError as e:
            print("OperationalError")
            raise e
            
    def closeConnection(self):
        self.conn.close()


    def setCursor(self):
        try:
            self.cur = self.conn.cursor()
        except InterfaceError as e:
            print("InterfaceError")
            print("connectionが見つかってないはず、")
            raise e
            
    def getCursor(self) -> psycopg2.extensions.connection.cursor:
        try:
            self.cur = self.conn.cursor()
            return self.cur
        except InterfaceError as e:
            print("InterfaceError")
            print("connectionが見つかってないはず、")
            raise e
            
    def closeCursor(self):
        self.conn.close()

# %%
""" ---------------------------------
# 
#  class
# 
#   ----------------------------------
""" 
from urllib.parse import urlparse
import mysql.connector
class TransactionManagerByMysql:
    
    def __init__(self):
        conn : psycopg2.extensions.connection
        cur  : psycopg2.extensions.connection.cursor
        url = urlparse('mysql://user:pass@localhost:3306/dbname')


    def setConnection(self):
        try:
            self.conn = mysql.connector.connect(host = url.hostname or 'localhost', 
                                                port = url.port or 3306, 
                                                user = url.username or 'root',
                                                password = url.password or '',
                                                database = url.path[1:],
                                            )
        except OperationalError as e:
            print("OperationalError")
            raise e
    
    def getConnection(self) -> psycopg2.extensions.connection:
        try:
            return mysql.connector.connect(host = url.hostname or 'localhost', 
                                                port = url.port or 3306, 
                                                user = url.username or 'root',
                                                password = url.password or '',
                                                database = url.path[1:],
                                            )
        except OperationalError as e:
            print("OperationalError")
            raise e
            
    def closeConnection(self):
        self.conn.close()


    def setCursor(self):
        try:
            self.cur = self.conn.cursor()
        except InterfaceError as e:
            print("InterfaceError")
            print("connectionが見つかってないはず、")
            raise e
            
    def getCursor(self) -> psycopg2.extensions.connection.cursor:
        try:
            self.cur = self.conn.cursor()
            return self.cur
        except InterfaceError as e:
            print("InterfaceError")
            print("connectionが見つかってないはず、")
            raise e
            
    def closeCursor(self):
        self.conn.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-51f4ea49c0d1> in <module>
#       6 """
#       7 from urllib.parse import urlparse
# ----> 8 import mysql.connector
#       9 class TransactionManagerByMysql:
#      10
#
# ModuleNotFoundError: No module named 'mysql'

# %%
""" ---------------------------------
# 
#  class
# 
#   ----------------------------------
""" 
class BaseDAO:
    
    def __init__(self, connection):
        self.conn = connection

# %%
""" ---------------------------------
# 
#  class
# 
#   ----------------------------------
""" 
class UserDAO(BaseDAO):
    
    def __init__(self, connection):
        # super(self, connection)
        self.conn = connection

        
    def getAll(self) -> list:
        userDTOs = list()
        try:
            cur = self.conn.cursor()
            cur.execute("SELECT * FROM account;")
            for rs in cur:
                userDTO = UserDTO()
                userDTO.setAllByTuple(rs)
                userDTOs.append(userDTO)
                # print(rs)
            cur.close()
        except InterfaceError as e:
            print("InterfaceError")
            print("connectionが見つかってないはず、")
            raise e
        finally:
            return userDTOs
        

    def getUserById(self, userId:int) -> UserDTO:
        userDTO = UserDTO()
        try:
            cur = self.conn.cursor()
            cur.execute("SELECT * FROM account WHERE id = %s;",(userId,))
            userDTO.setAllByTuple(cur.fetchone())
            cur.close()
        except InterfaceError as e:
            print("InterfaceError")
            print("connectionが見つかってないはず、")
            raise e
        finally:
            return userDTO

# %%
userId = 2;
tm = TransactionManagerByPostgres()
conn = tm.getConnection()
userDAO = UserDAO(conn)
userDTOs = userDAO.getAll()
userDTO = userDAO.getUserById(userId)
conn.close()
# userDTO.printUser()
# userDTOs[0].printUser()
# Out:
# 2
# testUser2
# testPass2
# 2
# None

# %%
""" ---------------------------------
# 
#  class
# 
#   ----------------------------------
""" 
class ResetPostgresDB:
    def resetAccount(self):
        tm = TransactionManagerByPostgres()
        conn = tm.getConnection()
        cur = conn.cursor()
        cur.execute("DROP TABLE IF EXISTS account;")
        cur.execute("CREATE TABLE account(id serial PRIMARY KEY, name varchar(20) NOT NULL, password varchar(20) NOT NULL, auth INTEGER NOT NULL, address varchar(40));")
        cur.execute("SELECT SETVAL('account_id_seq', 1000);")
        cur.execute("INSERT INTO account(name, password, auth) VALUES (%s, %s, %s)",("testUser1", "testPass1", 1))
        cur.execute("INSERT INTO account(name, password, auth) VALUES (%s, %s, %s)",("testUser2", "testPass2", 2))
        conn.commit()
        cur.close()
        conn.close()
        print("END")
resetDB = ResetPostgresDB()
resetDB.resetAccount()
